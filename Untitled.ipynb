# %% [markdown]
# # Final project: Predict movies box office
#
# 1712811 - Lê Trung Tiến \
# 1712742 - Nguyễn Tấn Tài

# %%
import aiohttp
import asyncio
import json
import os
from aiohttp import ClientSession
import pandas as pd

# %% [markdown]
# ## Collect data

# %%
# GET GENERAL DATA OF MOVIES AND WRITE TO FILE

# Keyword to find movies
KEYWORD = 'super'
# Default and constant movies per page = 10
NUMBER_OF_PAGES_TO_GET = 90

# Dataframe to save movie general details
data_short = pd.DataFrame(columns=['Title', 'Year', 'imdbID', 'Type', 'Poster'])

# We use async techique here
async def get_movie_short_async(page, session):
    url = f'http://www.omdbapi.com/?apikey=2889d713&s={KEYWORD}&page={page}&type=movie'
    try:
        response = await session.request(method='GET', url=url)
        response.raise_for_status()
#         print(f"Response status ({url}): {response.status}")
    except HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")
    except Exception as err:
        print(f"An error ocurred: {err}")
    response_json = await response.json()
    global data_short
    data_short = data_short.append(response_json['Search'], ignore_index=True)
    pass

# Call the above function concurrently to save time
async with ClientSession() as session:
    await asyncio.gather(*[get_movie_short_async(page, session) for page in range(1, NUMBER_OF_PAGES_TO_GET + 1)])
    
data_short.head()
data_short.to_csv('data_short.csv', index=False)
# Out:
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=3&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=10&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=14&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=9&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=82&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=29&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=57&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=1&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=5&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=11&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=20&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=19&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=17&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=55&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=18&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=13&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=72&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=15&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=32&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=46&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=48&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=28&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=22&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=24&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=62&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=50&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=42&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=67&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=23&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=16&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=44&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=41&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=30&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=12&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=8&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=4&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=2&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=25&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=78&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=59&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=39&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=33&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=88&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=60&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=79&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=43&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=34&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=69&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=6&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=45&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=47&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=84&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=66&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=21&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=64&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=54&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=51&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=75&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=81&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=83&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=7&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=71&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=37&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=85&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=70&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=52&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=68&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=58&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=49&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=77&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=74&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=89&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=65&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=87&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=76&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=73&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=40&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=36&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=35&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=61&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=86&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=38&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=27&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=90&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=26&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=63&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=31&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=80&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=53&type=movie): 200
# Response status (http://www.omdbapi.com/?apikey=2889d713&s=super&page=56&type=movie): 200

# %%
# GET DETAILS OF EACH MOVIES

# Dataframe to save movie details
data_detail = pd.DataFrame(columns=["Title", "Year", "Rated", "Released", "Runtime", "Genre", "Director", "Writer", "Actors", "Plot", "Language", "Country", "Awards", "Poster", "Ratings", "Metascore", "imdbRating", "imdbVotes", "imdbID", "Type", "DVD", "BoxOffice", "Production", "Website", "Response"])

async def get_movie_detail_async(imdb_id, session):
    url = f'http://www.omdbapi.com/?apikey=2889d713&i={imdb_id}&type=movie'
    try:
        response = await session.request(method='GET', url=url)
        response.raise_for_status()
#         print(f"Response status ({url}): {response.status}")
    except HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")
    except Exception as err:
        print(f"An error ocurred: {err}")
    response_json = await response.json()
    global data_detail
    data_detail = data_detail.append(response_json, ignore_index=True)
    pass

async with ClientSession() as session:
    await asyncio.gather(*[get_movie_detail_async(imdb_id, session) for imdb_id in data_short['imdbID']])
    
data_detail.head()
data_detail.to_csv('data_detail.csv', index=False)

# %% [markdown]
# ## Question to ask
# How much could the box office of a newly released film be?

# %% [markdown]
# ## Discover data

# %% [markdown]
# ### Read data from file

# %%
# Read data from file
data_df = pd.read_csv('data_detail.csv')
data_df.head()
# Number of rows and columns
data_df.shape

# Number of duplicated rows
data_df.duplicated().sum()

# Column meanings
# TODO

# Data types
data_df.dtypes
# Out:
# Title          object
# Year            int64
# Rated          object
# Released       object
# Runtime        object
# Genre          object
# Director       object
# Writer         object
# Actors         object
# Plot           object
# Language       object
# Country        object
# Awards         object
# Poster         object
# Ratings        object
# Metascore     float64
# imdbRating    float64
# imdbVotes      object
# imdbID         object
# Type           object
# DVD            object
# BoxOffice      object
# Production     object
# Website       float64
# Response         bool
# dtype: object

# %% [markdown]
# ### Useful columns to use

# %%
# As we see, the columns will be
useful_cols = ['Year', 'Rated', 'Runtime', 'Genre', 'Language', 'Country', 'Production']

# Why we dont use other columns:
# TODO

# %% [markdown]
# ### Preprocess data

# %%
# As we see, the useful columns are all have invalid data type (Object). Now we convert it to number / category type

# Let see the categories of each columns:
for useful_col in useful_cols:
    print(useful_col)
    print(data_df[useful_col].unique())
    print()
# Out:
# Year
# [2012 2017 1925 2001 2011 2007 2018 2019 2015 2010 2009 1996 1986 2013
#  2004 1989 1998 1973 1964 1971 2005 1992 2016 2014 1994 1972 2020 2006
#  1966 2008 1993 1985 1984 1937 1974 1978 2002 1991 1969 1979 2003 1995
#  1999 1981 1980 2000 1983 1988 1949 1976 1987 1982 1970 1990 2022 1967
#  1997 1975 1952 1977 1943 1960 2021 1934 1935 1947 1965]
#
# Rated
# [nan 'Not Rated' 'R' 'PG-13' 'TV-Y7' 'TV-Y7-FV' 'TV-MA' 'PG' 'TV-14'
#  'TV-PG' 'G' 'Approved' 'NOT RATED' 'UNRATED' 'Unrated' '14+' 'TV-G'
#  'M/12' 'PASSED' 'X' 'APPROVED']
#
# Runtime
# [nan '20 min' '92 min' '83 min' '120 min' '78 min' '4 min' '108 min'
#  '49 min' '94 min' '93 min' '52 min' '77 min' '75 min' '106 min' '30 min'
#  '87 min' '7 min' '1 h 59 min' '22 min' '84 min' '136 min' '86 min'
#  '96 min' '133 min' '12 min' '91 min' '200 min' '89 min' '95 min' '64 min'
#  '99 min' '5 min' '104 min' '60 min' '112 min' '100 min' '55 min'
#  '110 min' '103 min' '70 min' '240 min' '1 h 58 min' '2 min' '85 min'
#  '90 min' '98 min' '154 min' '1,325 min' '15 min' '74 min' '10 min'
#  '1 min' '13 min' '25 min' '105 min' '230 min' '58 min' '23 min' '24 min'
#  '141 min' '88 min' '46 min' '67 min' '180 min' '14 min' '59 min'
#  '101 min' '73 min' '18 min' '28 min' '9 min' '130 min' '50 min' '17 min'
#  '54 min' '16 min' '97 min' '121 min' '142 min' '66 min' '204 min'
#  '44 min' '6 min' '65 min' '118 min' '21 min' '43 min' '72 min' '41 min'
#  '19 min' '47 min' '3 min' '56 min' '32 min' '79 min' '115 min' '1 h'
#  '81 min' '27 min' '53 min' '194 min' '176 min' '140 min' '8 min' '71 min'
#  '48 min' '29 min' '76 min' '11 min' '102 min' '68 min' '82 min' '40 min'
#  '31 min' '42 min' '51 min' '127 min' '270 min' '175 min' '151 min'
#  '155 min' '26 min' '107 min' '45 min' '144 min' '135 min' '111 min'
#  '80 min' '69 min' '125 min' '57 min' '61 min' '114 min']
#
# Genre
# ['Sport' 'Short, Comedy' 'Short, Comedy, Horror' 'Action, Fantasy, Sci-Fi'
#  'Adventure, History'
#  'Animation, Action, Adventure, Comedy, Family, Sci-Fi'
#  'Animation, Short, Adventure, Comedy, Family' 'Action, Comedy, Sci-Fi'
#  'Horror, Sci-Fi, Thriller' 'Documentary' 'Comedy'
#  'Comedy, Fantasy, Sci-Fi'
#  'Animation, Action, Adventure, Comedy, Family, Fantasy, Sci-Fi'
#  'Animation, Action, Adventure, Comedy, Family' 'Reality-TV'
#  'Adventure, Animation, Comedy' 'Action, Crime, Drama' 'Music, Sport'
#  'Music' 'Animation, Short, Action, Family, Fantasy, Thriller'
#  'Crime, Drama' 'Action, Adventure, Thriller' 'Drama, Mystery'
#  'Animation, Short, Comedy' 'Action, Comedy, Family' 'Family, Fantasy'
#  'Action, Comedy, Drama' 'Comedy, Drama, Family' 'Short'
#  'Action, Adventure, Comedy, Horror, Sci-Fi, Thriller'
#  'Animation, Action, Adventure' 'Comedy, Drama' 'Adventure, Thriller'
#  'Thriller, Mystery' 'Animation, Comedy' 'Comedy, Crime, Mystery' 'News'
#  'Adventure, Comedy, Family, Fantasy, Sci-Fi' 'Animation, Short, Family'
#  'Action, Adventure, Sci-Fi, Thriller' 'Action, Adventure, Fantasy'
#  'Action, Adventure, Comedy' 'Animation' 'Comedy, Drama, Thriller'
#  'Crime, Drama, Horror, Thriller' 'Comedy, Mystery' 'Action, Sport'
#  'Animation, Short, Action, Adventure, Comedy, Fantasy, Sci-Fi'
#  'Comedy, Romance, Sci-Fi'
#  'Documentary, Animation, Adventure, Comedy, Horror, Music, Sci-Fi'
#  'Drama' 'Animation, Short' 'Action, Comedy, Crime, Drama, Thriller'
#  'Action, Adventure, Comedy, Fantasy, Sci-Fi' 'Biography, Drama'
#  'Documentary, Short' 'Short, Action, Adventure, Mystery, Thriller'
#  'Animation, Action, Adventure, Family, Fantasy, Sci-Fi'
#  'Documentary, Biography, Music' 'Horror'
#  'Animation, Comedy, Family, Sport' 'Action, Adventure, Fantasy, Sci-Fi'
#  'Animation, Short, Action, Fantasy' 'Short, Action, Comedy' nan
#  'Short, Drama, Sport' 'Animation, Family, Short'
#  'Animation, Short, Family, Fantasy' 'Comedy, Romance'
#  'Animation, Short, Action, Comedy, Sci-Fi' 'Family'
#  'Comedy, Crime, Horror, Mystery, Thriller' 'Action, Drama'
#  'Action, Adventure, Drama, Sci-Fi' 'Action' 'Short, Horror'
#  'Short, Music, Reality-TV' 'Romance' 'Action, Comedy' 'Drama, Comedy'
#  'Animation, Short, Comedy, Family' 'Short, Biography' 'Family, Sci-Fi'
#  'Short, Music' 'Drama, Mystery, Romance'
#  'Animation, Short, Action, Adventure, Sci-Fi'
#  'Adventure, Action, Fantasy' 'Animation, Sci-Fi'
#  'Animation, Adventure, Family' 'Action, Sci-Fi' 'Short, Drama, War'
#  'Short, Drama' 'Documentary, Sport' 'Action, Fantasy'
#  'Action, Comedy, Crime' 'Short, Comedy, Fantasy, Horror, Sci-Fi'
#  'Animation, Short, Adventure' 'Short, Comedy, Drama'
#  'Action, Comedy, Fantasy' 'Action, Adventure, Crime' 'Comedy, Fantasy'
#  'Animation, Short, Action, Comedy, Fantasy, Sci-Fi' 'Action, War'
#  'Comedy, Musical' 'Short, Comedy, Thriller' 'Documentary, Comedy'
#  'Animation, Drama, Sci-Fi' 'Animation, Comedy, Sci-Fi' 'Horror, Sci-Fi'
#  'Animation, Sci-Fi, War' 'Comedy, Short' 'Family, Animation'
#  'Animation, Comedy, Family, Sci-Fi'
#  'Action, Crime, Drama, Thriller, Sci-Fi'
#  'Action, Adventure, Crime, Sci-Fi' 'Comedy, Thriller'
#  'Short, Animation, Family' 'Animation, Action, Comedy, Family'
#  'Comedy, Family, Fantasy' 'Animation, Comedy, Family, Short' 'Thriller'
#  'Musical' 'Documentary, Animation, Short'
#  'Animation, Short, Comedy, Family, Fantasy' 'Comedy, Horror'
#  'Animation, Family' 'Documentary, History' 'Drama, Fantasy, Sport'
#  'Comedy, Sci-Fi, Musical' 'Animation, Action, Fantasy, Sci-Fi'
#  'Short, Action' 'Documentary, Drama' 'Music, Musical, Sport' 'Sci-Fi'
#  'Action, Drama, Fantasy' 'Animation, Adventure, Comedy, Fantasy'
#  'Animation, Family, Short, Comedy' 'Animation, Short, Adventure, Family'
#  'Action, Adventure, Drama'
#  'Comedy, Drama, Horror, Mystery, Romance, Thriller'
#  'Action, Comedy, Fantasy, Sci-Fi' 'Animation, Action, Sci-Fi'
#  'Comedy, Crime, Drama, Thriller' 'Action, Crime, Drama, Music, Thriller'
#  'Horror, Thriller' 'Comedy, Music' 'Adventure, Crime, Thriller'
#  'Short, Family' 'Animation, Action, Adventure, Family, Sci-Fi'
#  'Short, Adventure, Comedy'
#  'Documentary, Animation, Short, Action, Adventure, Family'
#  'Animation, Adventure, Sci-Fi' 'Adventure, Comedy, Thriller' 'Adventure'
#  'Short, Comedy, Fantasy' 'Documentary, Comedy, Sport'
#  'Action, Musical, Romance' 'Short, Comedy, Crime'
#  'Short, Comedy, Romance' 'Short, Fantasy, Horror' 'Comedy, Game-Show'
#  'Short, Drama, Sci-Fi, Thriller'
#  'Action, Adventure, Drama, Sci-Fi, Thriller'
#  'Documentary, Short, Thriller' 'Short, Crime, Drama'
#  'Short, Action, Adventure, Comedy' 'Short, Fantasy'
#  'Documentary, Short, Action' 'Short, Biography, Comedy' 'Comedy, Sport'
#  'Animation, Short, Action'
#  'Animation, Short, Action, Adventure, Comedy, Sci-Fi'
#  'Animation, Short, Action, Comedy, Family' 'Comedy, Horror, Sci-Fi'
#  'Drama, Family, Musical' 'Documentary, Music'
#  'Comedy, Family, Fantasy, Musical'
#  'Comedy, Drama, Horror, Mystery, Thriller' 'Documentary, Short, Drama'
#  'Family, Game-Show' 'Short, Action, Fantasy' 'Short, Adventure'
#  'Short, Action, Adventure, Fantasy, Sci-Fi' 'Crime' 'Short, Sport'
#  'Animation, Short, Drama' 'Short, Horror, Sci-Fi' 'Documentary, News'
#  'Comedy, Crime' 'Comedy, Talk-Show' 'Documentary, Action, Sport'
#  'Game-Show' 'Documentary, Short, Comedy' 'Adventure, Family, Sci-Fi'
#  'Action, Comedy, Horror' 'Comedy, Musical, Short, Horror'
#  'Documentary, Short, Sport' 'Animation, Short, Adventure, Fantasy'
#  'Talk-Show' 'Animation, Comedy, News, Sport, Talk-Show' 'Fantasy'
#  'Animation, Action, Comedy' 'Music, Talk-Show' 'Action, Biography'
#  'Short, Adventure, Comedy, Crime' 'Animation, Comedy, Family'
#  'Music, Comedy' 'Short, Comedy, Sci-Fi' 'Short, Action, Music'
#  'Short, Comedy, History' 'Action, Drama, Sport, Talk-Show'
#  'Drama, Sci-Fi' 'Western' 'Short, Adventure, Drama' 'Animation, Sport'
#  'Action, Comedy, Mystery' 'Short, Sci-Fi' 'Music, Short, Sport'
#  'Adventure, Crime' 'Short, Documentary' 'Animation, Adventure'
#  'Documentary, Sci-Fi' 'Action, Adventure, Fantasy, Romance, Sci-Fi'
#  'Action, Adventure, Biography' 'Short, Action, Horror'
#  'Action, Adventure, Comedy, Fantasy' 'Animation, Fantasy'
#  'Adventure, Comedy' 'Action, Romance']
#
# Language
# ['English' 'Japanese' 'Spanish' 'French' 'Italian' 'English, Italian'
#  'Bengali' 'Malayalam' nan 'Hindi' 'Finnish' 'German' 'Thai'
#  'Mandarin, English' 'English, German, French' 'Greek'
#  'English, Spanish, Filipino, German, Hindi' 'English, Japanese' 'Turkish'
#  'Tagalog, Filipino' 'Portuguese' 'Cantonese' 'Sinhalese'
#  'Mandarin, Tagalog' 'Telugu' 'Mandarin' 'Spanish, English'
#  'English, Hindi' 'Uzbek, Russian' 'Chinese' 'Filipino, Tagalog, English'
#  'Min Nan' 'Vietnamese' 'Danish' 'Korean, English' 'Filipino, Tagalog'
#  'Tamil, Telugu' 'German, English' 'English, Filipino, Tagalog'
#  'English, Chinese' 'French, English' 'Hebrew, Russian' 'Korean'
#  'Hindi, Japanese' 'Armenian' 'Italian, English' 'English, French' 'Tamil'
#  'Kannada' 'English, Spanish' 'Xhosa, English'
#  'Japanese, English, German, Spanish, French, Italian' 'Hebrew' 'Russian'
#  'Nepali' 'English, German' 'English, Turkish' 'Spanish, Korean, English'
#  'Turkish, Lithuanian' 'Indonesian' 'Serbo-Croatian' 'Polish'
#  'Telugu, Hindi' 'Punjabi' 'Dutch' 'Malay' 'Dutch, Persian'
#  'English, American Sign Language, French' 'Arabic, Sign Languages'
#  'English, Swahili' 'Chhattisgarhi']
#
# Country
# ['USA' 'Japan' 'Spain' 'USA, Germany' 'France' 'Italy' 'Bangladesh'
#  'India' nan 'Canada' 'Finland' 'West Germany, Switzerland' 'Thailand'
#  'Taiwan, South Korea' 'Italy, France, West Germany' 'Germany'
#  'UK, USA, Japan, France' 'Greece' 'West Germany' 'Australia, USA'
#  'Canada, Germany, USA' 'Australia' 'UK' 'Argentina' 'Turkey' 'Chile'
#  'Philippines' 'Brazil, Mexico' 'Hong Kong' 'South Africa' 'Sri Lanka'
#  'Hong Kong, Philippines' 'Dominican Republic' 'Taiwan' 'Brazil'
#  'Uzbekistan' 'Australia, New Zealand' 'China' 'Canada, USA'
#  'Taiwan, China' 'Vietnam' 'Denmark' 'Mexico' 'Germany, South Africa'
#  'South Korea' 'Qatar' 'Nigeria' 'China, USA' 'Israel'
#  'Italy, Hong Kong, Mexico' 'Germany, Austria' 'Armenia' 'Croatia'
#  'Canada, France' 'Italy, Spain, USA' 'USA, Japan' 'France, West Germany'
#  'New Zealand' 'Switzerland' 'Portugal' 'USA, UK, Denmark' 'Kazakhstan'
#  'Nepal' 'UK, Turkey, USA' 'Lithuania' 'Indonesia'
#  'Germany, Italy, Federal Republic of Yugoslavia' 'Japan, USA' 'Poland'
#  'Ireland, Canada' 'UK, South Korea' 'Russia' 'USA, Australia' 'Belgium'
#  'Serbia, Croatia' 'Netherlands' 'Saudi Arabia' 'UK, Switzerland, Hungary'
#  'France, Belgium' 'France, USA' 'Malaysia' 'Austria, Germany' 'Sweden'
#  'Qatar, Lebanon' 'Italy, USA' 'USA, France, Iceland, Switzerland'
#  'Austria']
#
# Production
# [nan 'Origin Releasing' 'DC Entertainment' 'Warner Bros. Animation'
#  'Stallion Media' 'DC Entertainment, Mattel, Warner Bros.'
#  'Toei Video Company' 'FLM Films' 'Retromedia Entertainment'
#  'Dimension Films, Miramax, View Askew Productions' 'CJ Entertainment'
#  'Allied Filmmakers, Hollywood Pictures, Cinergi Pictures Entertainment'
#  'Amblin Entertainment, Bad Robot'
#  'Cataland Films, Jersey Films, Broken Lizard Productions, Jersey Shore'
#  'Shemaroo'
#  'Lila 9th Productions, Ways &amp; Means, Higher Content, Neighborhood Watch, Om Films'
#  'RKO Radio Pictures Inc.'
#  'Regency Enterprises, Pariah Entertainment Group' 'Metro-Goldwyn-Mayer'
#  'RG Entertainment Ltd.' 'Reliance Entertainment'
#  'Purple Rose Productions' 'Banger Films, Eagle Rock Entertainment, Ltd.'
#  'Netflix' 'Tsuburaya Productions' 'TVA Films' 'Key Pix Productions'
#  'ABS-CBN Film Productions' 'Transcinema, El Pico S.A., TVI'
#  'Sixth Way Productions, Wabi Pictures'
#  'DC Entertainment, Warner Bros. Animation' 'The Asylum'
#  'Warner Bros., Sig Shore International' 'DC Comics'
#  'MarVista Entertainment, Unified Film Organization (UFO)' 'Icarus Films'
#  'Fandango' 'MTV Films'
#  'Marvel Animation, Walt Disney Company, Marvel Entertainment'
#  'Elita Film' 'Brat Films']

# %%
# First of all, we can see that there is a column whose type could be category but we have to preprocess it a little.
# That column is: Genre
all_gernes_in_one_list = []
for gerne in data_df['Genre']:
    all_gernes_in_one_list.extend(gerne.split(','))
    
print(all_gernes_in_one_list)

# OK, we can see that the columns with category data type are
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-5b7c11186525> in <module>
#       3 all_gernes_in_one_list = []
#       4 for gerne in data_df['Genre']:
# ----> 5     all_gernes_in_one_list.extend(gerne.split(','))
#       6
#       7 print(all_gernes_in_one_list)
#
# AttributeError: 'float' object has no attribute 'split'

# %%
# OK, hopefully the columns we choose dont have too much categories
# Now we calculate the percentage of every categories in each column

# %% [markdown]
# ### Number of rows and columns
